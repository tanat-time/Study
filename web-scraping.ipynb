# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import lxml
import json

# %%
url = "https://doc.dmcr.go.th/chart/co/75?menuid=1"
response = requests.get(url)

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="">
# <head>
# <base href="https://doc.dmcr.go.th/"/>
# <title>ปะการัง - ศูนย์ปฏิบัติการระดับกรม (DOC) กรมทรัพยากรณ์ทางทะเลและชายฝั่ง</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" id="viewport" name="viewport"/>
# <meta content="ปะการัง" name="keywords"/>
# <meta content="ปะการัง" name="description"/>
# <meta content="" name="author"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="" name="base_lang"/>
# <!-- META OPEN GRAPH (FB) -->
# <meta content="website" property="og:type"/>
# <meta content="https://doc.dmcr.go.th/chart/co/75?menuid=1" property="og:url"/>
# <meta content="DMCR" property="og:title"/>
# <meta content="DMCR" property="og:description"/>
# <meta content="https://doc.dmcr.go.th/front/template/default/assets/img/brand.jpg" property="og:image"/>
# <meta content="" property="og:site_name"/>
# <meta content="" property="og:locale"/>
# <meta content="" property="og:locale:alternate"/>
# <link href="https://doc.dmcr.go.th/front/template/default/assets/img/brand.jpg" rel="image_src"/>
# <!-- TWITTER CARD -->
# <meta content="summary" name="twitter:card"/>
# <meta content="" name="twitter:title"/>
# <meta content="" name="twitter:description"/>
# <meta content="" name="twitter:url"/>
# <meta content="" name="twitter:image:src"/>
# <!-- ICONS -->
# <link href="https://doc.dmcr.go.th/front/template/default/assets/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://doc.dmcr.go.th/front/template/default/assets/favicon/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="https://doc.dmcr.go.th/front/template/default/assets/favicon/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="https://doc.dmcr.go.th/front/template/default/assets/favicon/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="https://doc.dmcr.go.th/front/template/default/assets/favicon/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://doc.dmcr.go.th/front/template/default/assets/favicon/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="https://doc.dmcr.go.th/front/template/default/assets/favicon/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://doc.dmcr.go.th/front/template/default/assets/favicon/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="https://doc.dmcr.go.th/front/template/default/assets/favicon/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://doc.dmcr.go.th/front/template/default/assets/favicon/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://doc.dmcr.go.th/front/template/default/assets/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="https://doc.dmcr.go.th/front/template/default/assets/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://doc.dmcr.go.th/front/template/default/assets/favicon/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="https://doc.dmcr.go.th/front/template/default/assets/favicon/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="https://doc.dmcr.go.th/front/template/default/assets/css/import.css?u=20241105175112" rel="stylesheet" type="text/css"/>
# <link href="https://doc.dmcr.go.th/front/template/default/assets/js/chart/2.9.3/Chart.min.css?u=20241105175112" rel="stylesheet" type="text/css"/>
# <!-- CDN -->
# <link href="https://unpkg.com/aos@2.3.1/dist/aos.css" rel="stylesheet"/>
# <!-- CSS SOURCE -->
# <link href="https://doc.dmcr.go.th/front/template/default/assets/css/source.css?u=20241105175112" rel="stylesheet" type="text/css"/>
# <!-- CSS MODIFY -->
# <link href="https://doc.dmcr.go.th/front/template/default/assets/css/modify.css?u=20241105175112" rel="stylesheet" type="text/css"/>
# <link href="https://doc.dmcr.go.th/front/template/default/assets/font/flaticon.css?u=20241105175112" rel="stylesheet" type="text/css"/>
# <link href="https://doc.dmcr.go.th/front/template/default/assets/css/pdpa.css?u=20241105175112" rel="stylesheet" type="text/css"/>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-8EQ73P9YVQ"></script>
# <script>
# 	  window.dataLayer = window.dataLayer || [];
# 	  function gtag(){dataLayer.push(arguments);}
# 	  gtag('js', new Date());
#
# 	  gtag('config', 'G-8EQ73P9YVQ');
# 	</script>
# </head>
# <body>
# <div id="preload">
# <div class="preload">
# <div class="logo">
# <div>
# <div class="loader"></div>
# <div class="textpreload text-center mt-0 mb-5">ศูนย์ปฏิบัติการระดับกรม (DOC)</div>
# <img alt="preload" src="https://doc.dmcr.go.th/front/template/default/assets/img/static/preload.gif?u=20241105175112"/>
# <div style="clear: both; margin-top: 0;"></div>
# <div class="textpreload subtextPreload text-center">ข้อมูลมีขนาดใหญ่ โปรดรอสักครู่</div>
# </div>
# </div>
# </div>
# </div>
# <div class="global-container">
# <header class="site-header">
# <div class="topbar">
# <div class="container">
# <div class="row align-items-center height row-0">
# <div class="col">
# <div class="h-txt" data-aos="fade-left" data-aos-duration="400">
# <a class="link" href="/home" title="ศูนย์ปฏิบัติการระดับกรม (DOC)">
# <span class="title-header">ศูนย์ปฏิบัติการระดับกรม (DOC)</span><br/>กรมทรัพยากรทางทะเลและชายฝั่ง
# 						</a>
# </div>
# </div>
# <div class="col-auto">
# <div class="row row-0 height-topbar">
# <div class="col-auto">
# <div class="text-size" data-aos="fade-down" data-aos-duration="500">
# <ul class="item-list">
# <li class="sm active"><a class="link size-small" href="javascript:void(0)">ก</a></li>
# <li class="md"><a class="link size-medium" href="javascript:void(0)">ก</a></li>
# <li class="lg"><a class="link size-large" href="javascript:void(0)">ก</a></li>
# </ul>
# </div>
# </div>
# <div class="col d-none">
# <div class="text-color" data-aos="fade-down" data-aos-duration="600">
# <ul class="item-list">
# <li class="bw"><a class="link color-bw" href="javascript:void(0)" id="theme-style-2">C</a></li>
# <li class="nm active"><a class="link color-nm" href="javascript:void(0)" id="theme-style-3">C</a></li>
# <li class="by"><a class="link color-by" href="javascript:void(0)" id="theme-style-1">C</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="bottombar">
# <div class="container">
# <div class="action" data-aos="fade-left" data-aos-duration="1500">
# <a class="btn" href="https://www.dmcr.go.th" target="_blank">เข้าสู่เว็บ ทช.</a>
# </div>
# <div class="nav-size d-none" data-aos="fade-down" data-aos-duration="2000">
# <div class="txt d-none">ขนาด</div>
# <ul class="item-list">
# <li class="sm">
# <a class="link nav-size-small fzSmall active" href="javascript:void(0);" id="theme-style-1" title="ขนาดอักษรเล็ก">ก</a>
# </li>
# <li class="md">
# <a class="link nav-size-medium fzMedium" href="javascript:void(0);" id="theme-style-2" title="ขนาดอักษรกลาง">ก</a>
# </li>
# <li class="lg">
# <a class="link nav-size-large fzLarge" href="javascript:void(0);" id="theme-style-3" title="ขนาดอักษรใหญ่">ก</a>
# </li>
# </ul>
# </div>
# <div class="text-size d-lg-none" data-aos="fade-down" data-aos-duration="500">
# <ul class="item-list item_list">
# <li class="sm active"><a class="link size-small" href="javascript:void(0)">ก</a></li>
# <li class="md"><a class="link size-medium" href="javascript:void(0)">ก</a></li>
# <li class="lg"><a class="link size-large" href="javascript:void(0)">ก</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="mainbar shadow">
# <div class="container">
# <div class="brand" data-aos="fade-left" data-aos-duration="500">
# <a class="link" href="/home" title="ศูนย์ปฏิบัติการระดับกรม (DOC)">
# <img class="lazy" src="https://doc.dmcr.go.th//upload/core/pic-20201228160917035815-1.png"/>
# </a>
# </div>
# <div class="menu-mobile-btn d-none">
# <a class="btn-mobile" data-toggle="menu-mobile" href="javascript:void(0);">
# <span class="bar active"></span>
# <span class="bar active"></span>
# <span class="bar active"></span>
# <span class="bar active"></span>
# </a>
# </div>
# <div class="nav-mobile">
# <a class="btn-mobile" data-toggle="menu-mobile" href="javascript:void(0);">
# <div class="menu-mobile-btn">
# <span class="bar"></span>
# <span class="bar"></span>
# <span class="bar"></span>
# <span class="bar"></span>
# </div>
# <div class="txt">MENU</div>
# </a>
# </div>
# <div class="nav-menu" data-aos="fade-up" data-aos-duration="500">
# <div class="row row-0">
# <div class="col">
# <div class="item d-none">
# <div class="row row-0">
# <div class="col-6">
# <div class="text-size d-lg-none" data-aos="fade-down" data-aos-duration="500">
# <ul class="item-list item_list">
# <li class="sm active"><a class="link size-small" href="javascript:void(0)">ก</a></li>
# <li class="md"><a class="link size-medium" href="javascript:void(0)">ก</a></li>
# <li class="lg"><a class="link size-large" href="javascript:void(0)">ก</a></li>
# </ul>
# </div>
# </div>
# <div class="col d-none">
# <div class="text-color d-lg-none" data-aos="fade-down" data-aos-duration="600">
# <ul class="item-list item_list">
# <li class="bw"><a class="link color-bw" href="javascript:void(0)" id="">C</a></li>
# <li class="nm active"><a class="link color-nm" href="javascript:void(0)" id="">C</a></li>
# <li class="by"><a class="link color-by" href="javascript:void(0)" id="" style="color: #ff0;">C</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="item">
# <a class="link" href="/home">
# <span class="icon_house_alt"></span> หน้าแรก
# 							</a>
# </div>
# <div class="item dropdown">
# <a class="link none" data-toggle="dropdown" href="javascript:void(0)"></a>
# <a class="link click" href="javascript:void(0)">
# 																		ข้อมูลองค์กร
# 									</a>
# <ul class="dropdown-menu -menu-outer">
# <li>
# <a class="link" href="/pageredirect/menu-header/sg/bkd1NFpEV2V3RWIzUVdld0ViM1E=" target="_blank">เกี่ยวกับ ทช.</a>
# </li>
# <li>
# <a class="link" href="/pageredirect/menu-header/sg/clFaV2V3RWIzUQ==">บุคลากร</a>
# </li>
# <li>
# <a class="link" href="/pageredirect/menu-header/sg/clFWV2V3RWIzUQ==">ผลการใช้จ่ายงบประมาณ</a>
# </li>
# <li>
# <a class="link" href="/pageredirect/menu-header/sg/clFSV2V3RWIzUQ==">งบประมาณ</a>
# </li>
# </ul>
# </div>
# <div class="item dropdown">
# <a class="link none" data-toggle="dropdown" href="javascript:void(0)"></a>
# <a class="link active click" href="javascript:void(0)">
# 																		ทรัพยากรทางทะเล
# 									</a>
# <ul class="dropdown-menu -menu-outer">
# <li class="dropright">
# <a class="link" data-toggle="dropdown" href="javascript:void(0)">ป่าชายเลน</a>
# <ul class="dropdown-menu">
# <li class="dropdown">
# <a class="link" href="/pageredirect/menu-header/c/bkdJNFpEV2V3RWIzUVdld0ViM1E=">พื้นที่ป่าชายเลนคงสภาพ</a>
# </li>
# <li class="dropdown">
# <a class="link" href="/pageredirect/menu-header/c/bkdFNFpEV2V3RWIzUVdld0ViM1E=">ป่าชายหาด</a>
# </li>
# <li class="dropdown">
# <a class="link" href="/pageredirect/menu-header/c/bkdXNFpqV2V3RWIzUVdld0ViM1E=">ป่าพรุ</a>
# </li>
# </ul>
# </li>
# <li class="dropright">
# <a class="link" data-toggle="dropdown" href="javascript:void(0)">ปะการัง</a>
# <ul class="dropdown-menu">
# <li class="dropdown">
# <a class="link" href="/pageredirect/menu-header/c/bkdJNFp0V2V3RWIzUVdld0ViM1E=">พื้นที่แนวปะการัง</a>
# </li>
# <li class="dropdown">
# <a class="link" href="/pageredirect/menu-header/c/bkdPNFpqV2V3RWIzUVdld0ViM1E=">สถานภาพแนวปะการัง</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="link" href="/pageredirect/menu-header/sg/clFMV2V3RWIzUQ==">หญ้าทะเล</a>
# </li>
# </ul>
# </div>
# <div class="item dropdown">
# <a class="link none" data-toggle="dropdown" href="javascript:void(0)"></a>
# <a class="link click" href="javascript:void(0)">
# 																		การจัดการชายฝั่ง
# 									</a>
# <ul class="dropdown-menu -menu-outer">
# <li>
# <a class="link" href="/pageredirect/menu-header/sg/bkdTNFp0V2V3RWIzUVdld0ViM1E=">จำนวนหาด</a>
# </li>
# <li>
# <a class="link" href="/pageredirect/menu-header/sg/bkd5NFpEV2V3RWIzUVdld0ViM1E=">จำนวนเกาะ</a>
# </li>
# <li>
# <a class="link" href="/pageredirect/menu-header/sg/bkdPNFpEV2V3RWIzUVdld0ViM1E=">สถานภาพแนวชายฝั่ง</a>
# </li>
# <li>
# <a class="link" href="/pageredirect/menu-header/sg/bkdTNFpEV2V3RWIzUVdld0ViM1E=">ความยาวชายฝั่ง</a>
# </li>
# <li>
# <a class="link" href="/pageredirect/menu-header/sg/clF4V2V3RWIzUQ==">การฟื้นฟูชายฝั่ง</a>
# </li>
# </ul>
# </div>
# <div class="item dropdown">
# <a class="link none" data-toggle="dropdown" href="javascript:void(0)"></a>
# <a class="link click" href="javascript:void(0)">
# 																		ผลงานตามยุทธศาสตร์
# 									</a>
# <ul class="dropdown-menu -menu-outer">
# <li>
# <a class="link" href="/pageredirect/menu-header/sg/bkdFNFpEV2V3RWIzUVdld0ViM1E=">ปะการังเทียม</a>
# </li>
# <li>
# <a class="link" href="/pageredirect/menu-header/sg/bkdBNFpEV2V3RWIzUVdld0ViM1E=">ขยะทะเล</a>
# </li>
# <li>
# <a class="link" href="/pageredirect/menu-header/sg/bkdXNFpEV2V3RWIzUVdld0ViM1E=">งานวิจัย</a>
# </li>
# </ul>
# </div>
# <div class="item dropdown">
# <a class="link none" data-toggle="dropdown" href="javascript:void(0)"></a>
# <a class="link click" href="javascript:void(0)">
# 																		เครือข่ายการมีส่วนร่วม
# 									</a>
# <ul class="dropdown-menu -menu-outer">
# <li class="dropright">
# <a class="link" data-toggle="dropdown" href="javascript:void(0)">ชุมชนชายฝั่ง</a>
# <ul class="dropdown-menu">
# <li class="dropdown">
# <a class="link" href="/pageredirect/menu-header/c/bkd1NFpEV2V3RWIzUVdld0ViM1E=">กลุ่มชุมชนชายฝั่ง</a>
# </li>
# <li class="dropdown">
# <a class="link" href="/pageredirect/menu-header/c/bkdxNFpEV2V3RWIzUVdld0ViM1E=">สมาชิกชุมชนชายฝั่ง</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="link" href="/pageredirect/menu-header/sg/clFEV2V3RWIzUQ==">อาสาสมัครพิทักษ์ทะเล</a>
# </li>
# </ul>
# </div>
# <div class="item dropdown">
# <a class="link none" data-toggle="dropdown" href="javascript:void(0)"></a>
# <a class="link click" href="javascript:void(0)">
# 																		บริการประชาชน
# 									</a>
# <ul class="dropdown-menu -menu-outer">
# <li>
# <a class="link" href="/pageredirect/menu-header/sg/bkdxNFpEV2V3RWIzUVdld0ViM1E=" target="_blank">E-Daily Report</a>
# </li>
# <li>
# <a class="link" href="/pageredirect/menu-header/sg/bkdNNFpEV2V3RWIzUVdld0ViM1E=" target="_blank">ศูนย์ข้อมูลกลาง ทช.</a>
# </li>
# <li>
# <a class="link" href="/pageredirect/menu-header/sg/bkdJNFpEV2V3RWIzUVdld0ViM1E=" target="_blank">ระบบโครงการสำคัญ</a>
# </li>
# </ul>
# </div>
# </div>
# <!--<div class="col-auto">
# 						<div class="item dropdown-desktop">
# 							<div class="dropdown btn-desktop">
#
# 								<div class="menu-desktop-btn" id="dropdownMenuDes " data-toggle="dropdown">
# 									<a href="javascript:void(0);" class="btn-hamburger">
# 										<span class="bar active"></span>
# 										<span class="bar active"></span>
# 										<span class="bar active"></span>
# 										<span class="bar active"></span>
# 									</a>
# 								</div>
# 								<div id="dropdownID" class="dropdown-menu dropdown-menu-right dropdown-content" aria-labelledby="dropdownMenuDes">
#                                 <div class="item-dropdown">
# 										<a href="/chart/res" class=" ">งานวิจัย</a>
# 									</div>
#
# 								</div>
# 							</div>
# 						</div>
# 					</div>-->
# </div>
# </div>
# </div>
# </div>
# <div class="overlay" data-toggle="menu-overlay"></div>
# </header>
# <section class="site-container getmasterkey" data-gid="75" data-masterkey="co">
# <div class="breadcrumb-block" data-aos="fade-down" data-aos-duration="1000">
# <div class="container">
# <ol class="breadcrumb">
# <li>
# <a class="link" href="/home">
# <span class="icon_house_alt"></span>
#                         หน้าแรก
#                     </a>
# </li>
# <li>
# <a class="link" href="/chart/co">
#                             ปะการัง
#                         </a>
# </li>
# <li class="active nav-bar-name">ปะการัง</li>
# </ol>
# </div>
# </div>
# <div class="whead-top">
# <div class="container">
# <div class="whead aos-init aos-animate" data-aos="fade-down" data-aos-duration="2000" data-aos-once="true">
# <h2 class="h-title">
# <span class="-h-title-1 text-primary">
#                                 ปะการัง
#                             </span> <br/>
# </h2>
# </div>
# </div>
# </div>
# <div class="default-block inner-chart">
# <div class="head-banner">
# <div class="container">
# <div class="filter" style="position: relative; z-index:100;">
# <div class="row align-items-center row-0">
# <div class="col-auto">
# <div class="txt">ปี</div>
# </div>
# <div class="col">
# <select class="select-control" data-id="hb-table-tab" id="year" name="year" onchange="resetSwap(this,'sec1');" size="1" style="width: 100%;">
# <option value="106">
#                                         2566</option>
# <option selected="" value="88">
#                                         2565</option>
# <option value="81">
#                                         2564</option>
# <option value="80">
#                                         2563</option>
# <option value="79">
#                                         2562</option>
# <option value="78">
#                                         2561</option>
# <option value="89">
#                                         2560</option>
# <option value="101">
#                                         2559</option>
# <option value="100">
#                                         2558</option>
# <option value="99">
#                                         2557</option>
# <option value="98">
#                                         2556</option>
# <option value="97">
#                                         2555</option>
# <option value="96">
#                                         2554</option>
# <option value="95">
#                                         2553</option>
# <option value="94">
#                                         2552</option>
# <option value="93">
#                                         2551</option>
# <option value="92">
#                                         2550</option>
# <option value="91">
#                                         2549</option>
# <option value="90">
#                                         2548</option>
# <option value="105">
#                                         2547</option>
# </select>
# </div>
# </div>
# </div>
# <div class="head-slider">
# <div class="item">
# <div class="row align-items-center height">
# <div class="col-lg-6 order-2 order-lg-1 showselectyear">
# <div class="annual-budget pt_10 d-none d-lg-block" data-aos="fade-down" data-aos-duration="1000">
# <h2 class="h-title">
# <span class="-h-title-1">
#                                                 ปะการัง
#                                             </span> <br/>
#                                             ปี <strong class="textYear"></strong> <br/>
# <small class="textDetail-1"></small>
# </h2>
# </div>
# <div class="check-list chart-1-notfound chart-detail chart-1-notfound-1" data-aos="fade-up" data-aos-duration="1200">
# <div class="" id="chart-1-HTML"></div>
# </div>
# <div class="switch-div chart-1-notfound chart-1-notfound-1" data-aos="fade-right" data-aos-duration="1000">
# <ul class="item-list tab-list" id="hbTab" role="tablist">
# <li class="item">
# <a class="link link_icon active clickChart1 clicktab-chart" data-id="hb-chart-tab" data-num="1" href="javascript:void(0);" id="hb-chart-tab1" onclick="swap(this)">
# <span class="img-nm"><img src="https://doc.dmcr.go.th/front/template/default/assets/img/icon/donut-chart.svg"/></span>
# <span class="img-by" style="display:none;"><img src="https://doc.dmcr.go.th/front/template/default/assets/img/icon/donut-chart-by.svg"/></span>
# </a>
# </li>
# <li class="item">
# <a class="link clickTable1 clicktab-table" data-id="hb-table-tab" data-num="1" href="javascript:void(0);" id="hb-table-tab1" onclick="swap(this,1)">
# <span class="fa fa-table"></span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="col-lg-6 order-1 order-lg-2">
# <div class="annual-budget pt_10 d-block d-lg-none" data-aos="fade-down" data-aos-duration="1000">
# <h2 class="h-title">
# <span class="-h-title-1">
#                                                 ปะการัง
#                                             </span><br/>
#                                             ปี <strong class="textYear"></strong>
# <br/>
# <small class="textDetail-1"></small>
# </h2>
# </div>
# <input id="masterkey" name="masterkey" type="hidden" value="co"/>
# <div class="clearfix"></div>
# <div class="tab-box hidesection1 hidesection1-1" id="hbTabContent">
# <div class="tab-chart showChart1 active hb-chart-tab-click" id="hb-chart1">
# <div class="chart-bar">
# <div class="chart-1" data-label="กลุ่ม">
# <canvas class="chartjs d-none" height="600" id="chart-1" width="600"></canvas>
# <figure class="highcharts-figure">
# <div id="chart-1-1-HTMLCharts">
# </div>
# </figure>
# </div>
# </div>
# </div>
# <div class="tab-table showTable1 hb-table-tab-click" id="hb-table1">
# <div class="mcscrollX">
# <div class="chart-1">
# <div id="chart-1-1-table"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="chart-1-datanotfound chart-1-datanotfound-1 text-light" style="display:none;">
# <div>
# <i aria-hidden="true" class="fa fa-exclamation-circle fa-2x"></i><br/><br/>ไม่พบข้อมูล
#                                             </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="section-2">
# <div class="spending-plan hidesection2">
# <div class="container">
# <div class="row">
# <div class="col">
# <div class="row">
# <div class="col-auto -img-country-col">
# <div class="i-title -img-country">
# <img alt="" class="lazy loading" data-was-processed="true" src=""/>
# </div>
# </div>
# <div class="col">
# <div class="h-content" data-aos="fade-right" data-aos-duration="1000">
# <h2 class="title text-primary">
#                                                 ข้อมูลปะการังรายเขต</h2>
# </div>
# </div>
# </div>
# </div>
# <div class="col-auto chart-2-notfound">
# <div class="switch-div d-none d-md-block" data-aos="fade-left" data-aos-duration="1000">
# <ul class="item-list tab-list" id="spTab">
# <li class="item">
# <a class="link active link-primary" data-id="sp-chart-tab" href="javascript:void(0);" id="sp-chart-tab" onclick="swap(this);">
# <span class="fa fa-bar-chart"></span>
# </a>
# </li>
# <li class="item">
# <a class="link link-primary" data-id="sp-table-tab" href="javascript:void(0);" id="sp-table-tab" onclick="swap(this);">
# <span class="fa fa-table"></span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="tab-box chart-2-notfound" data-aos="fade-down" data-aos-duration="1000" id="spTabContent">
# <div class="tab-chart active" id="sp-chart">
# <div class="mcscrollX">
# <div class="chart-bar">
# <div class="chart-2" data-label="อ่าว">
# <canvas class="chart-height d-none" id="chart-2"></canvas>
# <figure class="highcharts-figure">
# <div id="chart-2-HTMLCharts"></div>
# </figure>
# </div>
# </div>
# </div>
# <div class="chart-bar-title">
# <div class="list_chart_detail" id="chart-2-HTML"></div>
# </div>
# </div>
# <div class="tab-table fade" id="sp-table">
# <div class="mcscrollX">
# <div class="chart-2">
# <div id="chart-2-table"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="switch-div d-block d-md-none" data-aos="fade-left" data-aos-duration="1000">
# <ul class="item-list nav" id="spTab" role="tablist">
# <li class="nav-item">
# <a class="link nav-link active link-primary" data-toggle="tab" href="#sp-chart" id="sp-chart-tab">
# <span class="fa fa-bar-chart"></span>
# </a>
# </li>
# <li class="nav-item">
# <a class="link nav-link link-primary" data-toggle="tab" href="#sp-table" id="sp-table-tab">
# <span class="fa fa-table"></span>
# </a>
# </li>
# </ul>
# </div>
# <div class="banner-slide-box" data-aos="fade-up" data-aos-duration="2000">
# <div class="banner-slider -banner-append"></div>
# </div>
# <div class="chart-2-datanotfound" style="display:none;">
# <div>
# <i aria-hidden="true" class="fa fa-exclamation-circle fa-2x"></i><br/><br/>ไม่พบข้อมูล
#                             </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="section-end -bg-co">
# <div class="container chart-group testhide">
# <div class="menu-mobile-list">เลือกเมนู</div>
# <div class="tab-head tabhead-mobile" data-aos="fade-down" data-aos-duration="1000">
# <div class="btn-close"><span class="fa fa-times"></span> ปิดเมนู</div>
# <div class="groupload">
# <div class="menu-list item-list nav col5-item" id="sc-endTabH" role="tablist">
# <div class="slider">
# <div class="item">
# <div class="nav-item item-w">
# <a class="clickTabChart link nav-link clickTab active" data-id="cp-table-tab" data-index="1" href="javascript:void(0)" onclick="resetSwap(this);">
#                                                 พื้นที่แนวปะการัง (ไร่)
#                                             </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="tab-content" data-aos="fade-up" data-aos-duration="1000" id="sc-endTabContent">
# <div aria-labelledby="sc-end-tab1" class="tab-pane fade show TabChartActive" id="sc-end1" role="tabpanel">
# <div class="h-content" data-aos="fade-down" data-aos-duration="1000">
# <div class="row align-items-center">
# <div class="col-auto -img-group-col" style="display: none;">
# <div class="i-title -img-group">
# <img alt="icon-menu" class="lazy loading" data-was-processed="true" src=""/>
# </div>
# </div>
# <div class="col">
# <h2 class="title">พื้นที่แนวปะการัง (ไร่)</h2>
# </div>
# <div class="col-auto">
# <div class="filter">
# <div class="row align-items-center row-0">
# <div class="col-auto">
# <div class="txt">หมวดหมู่</div>
# </div>
# <div class="col">
# <select class="selectSubGroup select-control" data-chart="1" id="subGroupID-1" name="subGroupID-1" size="1" style="width: 100%;">
# <option value="all">ทั้งหมด</option>
# <option value="188">อ่าวไทย</option>
# <option value="264">อันดามัน</option>
# </select>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-12 chart-group-1-datanotfound chart-group-datanotfound text-light" style="display:none;">
# <div>
# <i aria-hidden="true" class="fa fa-exclamation-circle fa-2x"></i><br/><br/>ไม่พบข้อมูล
#                                 </div>
# </div>
# <div class="tab-box chart-group-1-tab" data-aos="fade-up" data-aos-duration="1000" id="cpTabContent1">
# <div class="tab-chart chartActive active" id="cp-chart1">
# <div class="height-chart">
# <div class="">
# <div class="chart-bar chart-group">
# <div class="chart-group-1" data-id="75" data-label="พื้นที่แนวปะการัง (ไร่)" data-method="ave">
# <canvas class="chart-height d-none" height="400" id="chart-group-1" width="400"></canvas>
# <figure class="highcharts-figure">
# <div class="chart-g-width" id="chart-group-1-HTML-Chart"></div>
# </figure>
# </div>
# </div>
# <div class="text-center text-light d-block d-md-none">
#                                                 &lt;&lt; เลื่อนไปทางซ้าย หรือ ขวา&gt;&gt;
#                                             </div>
# </div>
# <div class="chart-bar-title">
# <div class="" id="chart-group-1-HTML"></div>
# </div>
# </div>
# </div>
# <div class="tab-table TabChartActive" id="cp-table1">
# <div class="height-chart">
# <div class="mcscrollX">
# <div id="chart-group-1-table"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="switch-div chart-group-1-tab" data-aos="fade-down" data-aos-duration="1000">
# <ul class="item-list tab-list" id="cpTab1">
# <li class="item">
# <a class="link chartActive1 active" data-id="cp-chart-tab" data-num="1" href="javascript:void(0);" id="cp-chart-tab1" onclick="swap(this);">
# <span class="fa fa-bar-chart"></span>
# </a>
# </li>
# <li class="item">
# <a class="link nav-link TabChartActive1 cl-cptable" data-id="cp-table-tab" data-num="1" href="javascript:void(0);" id="cp-table-tab1" onclick="swap(this);">
# <span class="fa fa-table"></span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <div class="cookieconsent">
# </div>
# <footer class="site-footer">
# <div class="main-footer">
# <div class="footer-address">
# <div class="container">
# <div class="row">
# <div class="col-lg-6">
# <div class="address" data-aos="fade-down" data-aos-duration="1000">
# <figure class="brand">
# <img alt="ศูนย์ข้อมูลกลางด้านทรัพยากรทางทะเลและชายฝั่ง Central Information Center for Marine and Coastal Resources" class="img-logo-ft" src="https://doc.dmcr.go.th/front/template/default/assets/img/static/footer-logo.png"/>
# </figure>
# <div class="title">
# <h2 class="title-footer">ศูนย์ปฏิบัติการระดับกรม <br/> กรมทรัพยากรทางทะเลและชายฝั่ง</h2>
# <p class="subtitle-footer">กระทรวงทรัพยากรธรรมชาติและสิ่งแวดล้อม</p>
# </div>
# </div>
# </div>
# <div class="col-lg-6">
# <div class="address contact" data-aos="fade-down" data-aos-duration="1000">
# <div class="address-info">
# <div class="row row-0">
# <div class="col-auto">
# <div class="thumb">
# <div class="cover">
# <span class="flaticon-placeholder"></span>
# </div>
# </div>
# </div>
# <div class="col">
# <div class="inner -api-address"></div>
# </div>
# </div>
# <div class="row row-0 pt-address-ft">
# <div class="col-md-4 mb-footer">
# <div class="row row-0" div="">
# <div class="col-auto">
# <div class="thumb">
# <div class="cover">
# <span class="flaticon-phone-call"></span>
# </div>
# </div>
# </div>
# <div class="col d-flex align-items-center">
# <div class="inner">
# <a class="link -api-tel-1-call" href="tel:">
# <p class="text -api-tel-1">
# </p>
# </a>
# <a class="link -api-tel-2-call" href="tel:">
# <p class="text -api-tel-2">
# </p>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-footer">
# <a class="link" style="cursor: unset;">
# <div class="row row-0" div="">
# <div class="col-auto">
# <div class="thumb">
# <div class="cover">
# <span class="flaticon-printer"></span>
# </div>
# </div>
# </div>
# <div class="col d-flex align-items-center">
# <div class="inner">
# <p class="text fax -api-fax">
# </p>
# </div>
# </div>
# </div>
# </a>
# </div>
# <div class="col-md-4 mb-footer">
# <a class="link -api-email-to" href="mailto:">
# <div class="row row-0" div="">
# <div class="col-auto">
# <div class="thumb">
# <div class="cover">
# <span class="flaticon-message"></span>
# </div>
# </div>
# </div>
# <div class="col d-flex align-items-center">
# <div class="inner">
# <p class="text -api-email">
# </p>
# </div>
# </div>
# </div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="footer-info">
# <div class="container">
# <div class="row row-0 pt-footer-info">
# <div class="col-lg-8 col-md-12">
# <div class="wrapper" data-aos="fade-up" data-aos-duration="1000">
# <div class="desc -api-policy">
# </div>
# </div>
# <div class="policy-footer">
# <div class="row align-items-center w-policy">
# <div class="col">
# <ul class="policy-list" id="get_menu_policy">
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="col-lg-4 col-md-12">
# <div class="standard" data-aos="fade-up" data-aos-duration="1000">
# <div class="ipv6">
# <a class="link" href="http://ipv6-test.com/validate.php?url=referer" rel="nofollow" target="_blank" title="ipv6 ready'">
# <img alt="ipv6 ready" src="https://doc.dmcr.go.th/front/template/default/assets/img/icon/button-ipv6.png" title="ipv6 ready"/>
# </a>
# </div>
# <div class="wcag">
# <a class="link" href="https://www.w3.org/WAI/WCAG2A-Conformance" rel="nofollow" target="_blank" title="Explanation of WCAG 2.0 Level A Conformance">
# <img alt="Level A conformance, W3C WAI Web Content Accessibility Guidelines 2.0" src="https://www.w3.org/WAI/wcag2A" style="-webkit-user-select: none"/>
# </a>
# </div>
# <div class="w3c">
# <a class="link" href="http://jigsaw.w3.org/css-validator/check/referer" target="_blank">
# <img alt="Valid CSS!" src="http://jigsaw.w3.org/css-validator/images/vcss?v=20161016" style="BORDER-TOP: 0px; HEIGHT: 31px; BORDER-RIGHT: 0px; WIDTH: 88px; BORDER-BOTTOM: 0px; BORDER-LEFT: 0px"/>
# </a>
# </div>
# </div>
# <div class="social" data-aos="fade-up" data-aos-duration="1200">
# <ul class="social-list">
# <li class="item"><a class="link -api-social-fb"><img alt="fb" class="img-social" src="https://doc.dmcr.go.th/front/template/default/assets/img/icon/social-fb.png"/></a></li>
# <li class="item"><a class="link -api-social-tw"><img alt="twitter" class="img-social" src="https://doc.dmcr.go.th/front/template/default/assets/img/icon/social-x-tw.png"/></a></li>
# <li class="item"><a class="link -api-social-yt"><img alt="youtube" class="img-social" src="https://doc.dmcr.go.th/front/template/default/assets/img/icon/social-yt.png"/></a></li>
# <li class="item"><a class="link -api-social-ig"><img alt="IG" class="img-social" src="https://doc.dmcr.go.th/front/template/default/assets/img/icon/social-ig.png"/></a></li>
# <li class="item"><a class="link -api-social-li"><img alt="line" class="img-social" src="https://doc.dmcr.go.th/front/template/default/assets/img/icon/social-li.png"/></a></li>
# <li class="item"><a class="link -api-social-tt"><img alt="tiktok" class="img-social" src="https://doc.dmcr.go.th/front/template/default/assets/img/icon/social-tt.png"/></a></li>
# <li class="item"><a class="link" href="/weadmin/" target="_blank"><img alt="weadmin" class="img-social" src="https://doc.dmcr.go.th/front/template/default/assets/img/icon/social-ic2.png"/></a></li>
# </ul>
# </div>
# <div class="footer-bar" data-aos="fade-in" data-aos-duration="2000">
# <!-- Histats.com  START  (standard)-->
# <script>
# 								document.write(unescape("%3Cscript src=%27https://s10.histats.com/js15.js?v=0.75385500 1512618066%27 type=%27text/javascript%27%3E%3C/script%3E"));
# 								</script>
# <a href="http://www.histats.com" rel="nofollow" target="_blank" title="free flash stats">
# <script>
# 								try {Histats.start(1,724355,4,1032,150,25,"00011111");
# 								Histats.track_hits();} catch (err){};
# 								</script>
# </a>
# <noscript>
# <a href="http://www.histats.com" rel="nofollow" target="_blank" title="free flash stats">
# <img alt="free flash stats" src="http://sstatic1.histats.com/0.gif?724355&amp;101" title="free flash stats">
# </img></a>
# </noscript>
# <!--  Histats.com  END  -->
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <a class="boxdestopsite" href="https://doc.dmcr.go.th/chart/co/75?menuid=1&amp;viewport=desktop">
# 						เรียกดูเว็บไซต์แบบเดสก์ท็อป <span id="destopsite">คลิก</span>
# </a>
# <div class="Totop">
# <span aria-hidden="true" class="fa fa-chevron-up"></span>
# </div>
# </footer></div>
# <input id="yearDef" name="yearDef" type="hidden" value="">
#
# <div aria-hidden="true" aria-labelledby="exampleModalCenterTitle" class="modal fade" id="modal_box" role="dialog" tabindex="-1">
# <div class="modal-dialog modal-dialog-centered" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <h5 class="modal-title" id="exampleModalCenterTitle">Modal title</h5>
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span aria-hidden="true">×</span>
# </button>
# </div>
# <div class="modal-body">
# 				...
# 			</div>
# <div class="modal-footer">
# <button class="btn btn-secondary" data-dismiss="modal" type="button">Close</button>
# <button class="btn btn-primary" type="button">Save changes</button>
# </div>
# </div>
# </div>
# </div>
# <div id="modal-html-policy"></div>
# <div class="modal-block">
# <div class="modal fade policy" id="modal-policy" role="dialog">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-body">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">×</button>
# <div class="wrapper">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- JS SOURCE -->
# <script src="https://doc.dmcr.go.th/front/template/default/assets/js/jquery-2.1.4.min.js?u=20241105175112"></script>
# <!-- <script src="https://doc.dmcr.go.th/front/template/default/assets/js/jquery-3.2.1.min"></script> -->
# <script src="https://doc.dmcr.go.th/front/template/default/assets/js/popper.min.js?u=20241105175112"></script>
# <script src="https://doc.dmcr.go.th/front/template/default/assets/js/jquery-ui.min.js?u=20241105175112"></script>
# <script src="https://doc.dmcr.go.th/front/template/default/assets/js/jquery.ui.touch-punch.min.js?u=20241105175112"></script>
# <script src="https://doc.dmcr.go.th/front/template/default/assets/js/jquery.easing-1.3.min.js?u=20241105175112"></script>
# <script src="https://doc.dmcr.go.th/front/template/default/assets/js/modernizr-3.6.0.min.js?u=20241105175112"></script>
# <script src="https://doc.dmcr.go.th/front/template/default/assets/js/bootstrap.min.js?u=20241105175112"></script>
# <script src="https://doc.dmcr.go.th/front/template/default/assets/js/validator.min.js?u=20241105175112"></script>
# <script src="https://doc.dmcr.go.th/front/template/default/assets/js/wow.min.js?u=20241105175112"></script>
# <script src="https://doc.dmcr.go.th/front/template/default/assets/js/select2.min.js?u=20241105175112"></script>
# <script src="https://doc.dmcr.go.th/front/template/default/assets/js/jquery.fancybox.min.js?u=20241105175112"></script>
# <script src="https://doc.dmcr.go.th/front/template/default/assets/js/jquery.mCustomScrollbar.min.js?u=20241105175112"></script>
# <script src="https://doc.dmcr.go.th/front/template/default/assets/js/slick.js?u=20241105175112"></script>
# <!-- <script src="https://doc.dmcr.go.th/front/template/default/assets/js/slick.min.js?u=20241105175112"></script> -->
# <script src="https://doc.dmcr.go.th/front/template/default/assets/js/slick-limitdot.js?u=20241105175112"></script>
# <script src="https://doc.dmcr.go.th/front/template/default/assets/js/lazyload.min.js?u=20241105175112"></script>
# <script src="https://doc.dmcr.go.th/front/template/default/assets/js/trunk8.min.js?u=20241105175112"></script>
# <script src="https://doc.dmcr.go.th/front/template/default/assets/js/jquery.matchHeight-min.js?u=20241105175112"></script>
# <script src="https://doc.dmcr.go.th/front/template/default/assets/js/jquery.sticky-sidebar.min.js?u=20241105175112"></script>
# <script src="https://doc.dmcr.go.th/front/template/default/assets/js/sticky-sidebar.min.js?u=20241105175112"></script>
# <script src="https://doc.dmcr.go.th/front/template/default/assets/js/scrolling-nav.js?u=20241105175112"></script>
# <!-- CDN -->
# <script src="https://unpkg.com/aos@2.3.1/dist/aos.js?u=20241105175112"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/Chart.js/2.5.0/Chart.min.js?u=20241105175112"></script>
# <!-- <script src="https://cdnjs.cloudflare.com/ajax/libs/Chart.js/2.9.3/Chart.min.js?u=20241105175112" integrity="sha512-s+xg36jbIujB2S2VKfpGmlC3T5V2TF3lY48DX7u2r9XzGzgPsa6wTpOQA7J9iffvdeBN0q9tKzRxVxw1JviZPg==" crossorigin="anonymous"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/Chart.js/2.9.3/Chart.bundle.min.js?u=20241105175112" integrity="sha512-vBmx0N/uQOXznm/Nbkp7h0P1RfLSj0HQrFSzV8m7rOGyj30fYAOKHYvCNez+yM8IrfnW0TCodDEjRqf6fodf/Q==" crossorigin="anonymous"></script> -->
# <!-- JS MAIN -->
# <script src="https://doc.dmcr.go.th/front/template/default/assets/js/fontsize.js?u=20241105175112"></script>
# <script src="https://doc.dmcr.go.th/front/template/default/assets/js/theme-style.js?u=20241105175112"></script>
# <script src="https://doc.dmcr.go.th/front/template/default/assets/js/cookie.js?u=20241105175112"></script>
# <script src="https://doc.dmcr.go.th/front/template/default/assets/js/main.js?u=20241105175112"></script>
# <script src="https://doc.dmcr.go.th/front/template/default/assets/js/pdpa.js?u=20241105175112"></script>
# <!-- setting web -->
# <script src="https://doc.dmcr.go.th/front/template/default/assets/js/settingWeb.js?u=20241105175112"></script>
# <script src="https://doc.dmcr.go.th/front/template/default/assets/charts/highcharts.js?u=20241105175112"></script>
# <script src="https://doc.dmcr.go.th/front/template/default/assets/js/develop.js?u=20241105175112"></script>
# <!-- JS CONCAT -->
# <!-- <script src="https://doc.dmcr.go.th/front/template/default/assets/js/script.concat.js"></script> -->
# <script src="https://doc.dmcr.go.th/front/controller/script/chart/js/script.js" type="text/javascript"></script><script src="https://doc.dmcr.go.th/front/controller/script/chart/js/script_html.js" type="text/javascript"></script><script>
# 	var raf = window.requestAnimationFrame || window.mozRequestAnimationFrame || window.webkitRequestAnimationFrame || window.msRequestAnimationFrame;
# </script>
# </input></body>
# </html>

# %%
try:
    tables = pd.read_html(str(soup))
    if not tables:
        raise ValueError("No tables found in the HTML file.")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Error: html5lib not found, please install it

# %%
import requests

from bs4 import BeautifulSoup

def download_page(url):
    response = requests.get(url)
    response.raise_for_status()
    return response.text

# %%
download_page(url)

# %%
def main(url):
    content = download_page(url)
    soup = BeautifulSoup(content, 'html.parser')
    result = {}
    for row in soup.table.find_all('tr'):
       row_header = row.th.get_text()
       row_cell = row.td.get_text()
       result[row_header] = row_cell
    with open('book_table.json', 'w') as storage_file:
       storage_file.write(json.dumps(result))

# %%
main(url)
